# %%
import numpy as np

speed = [99,45,87,93,86,82,99,90,67,54,36,89]
#x = np.mean(speed)
x = np.median(speed)
print(x)
# Out:
# 86.5

# %%
from scipy import stats
speed = [99,45,87,93,86,82,99,90,67,54,36,89]

x = stats.mode(speed)
print(x)
# Out:
# ModeResult(mode=np.int64(99), count=np.int64(2))
